# %%
n = int(input())
kg_at_least = int(input())  # Weight of meat we need.
kg_threshhold_previous = 0  # Weight of previous threshhold.
total = 0  # Total price.
buttom_stop = 0  # Calculation continues when buttom_stop = 0.
for i in range(n):  # Run for n times.
    kg = int(input())
    price = int(input())
    if buttom_stop == 0:
        # Situation when meat we need is over or equal to threshhold.
        if kg_at_least >= kg:
            total += price*(kg-kg_threshhold_previous)
            # Update weight of previous threshhold.
            kg_threshhold_previous = kg
        # Situation when meat we need is less than threshhold.
        elif kg_at_least < kg:
            total += price*(kg_at_least - kg_threshhold_previous)
            # Calculation stops when buttom_stop = 1.
            buttom_stop = 1
print(total)

# %%
n = int(input())
kg_at_least = int(input())  # Weight of meat we need.
kg_threshhold_previous = 0  # Weight of previous threshhold.
total = 0  # Total price.
buttom_stop = 0  # Calculation continues when buttom_stop = 0.
for i in range(n-1):
    kg = int(input())
    price = int(input())
    if buttom_stop == 0:
        # Situation when meat we need is over or equal to threshhold.
        if kg_at_least >= kg:
            total += price*(kg-kg_threshhold_previous)
            # Update weight of previous threshhold.
            kg_threshhold_previous = kg
        # Situation when meat we need is less than threshhold.
        elif kg_at_least < kg:
            total += price*(kg_at_least - kg_threshhold_previous)
            # Calculation stops when buttom_stop = 1.
            buttom_stop = 1
# Last input of t and r.
threshhold_last = int(input())
price_last = int(input())
# Calculation stops when buttom_stop = 1.
if buttom_stop == 0:
    # Situation when meat we need is over last threshhold.
    if kg_at_least > threshhold_last:
        total += price_last*(kg_at_least - threshhold_last)
    # Situation when meat we need is less than or equal to last threshhold.
    else:
        total += price_last*(kg_at_least - kg_threshhold_previous)
print(total)
# Out:
# 3
# 45
# 10
# 55
# 30
# 40
# 1000
# 35
# 1875

# %%
n = int(input())
kg_at_least = int(input())  # Weight of meat we need.
kg_threshhold_previous = 0  # Weight of previous threshhold. 
total = 0  # Total price.
buttom_stop = 0  # Calculating continues when buttom_stop = 0.

for i in range(n-1):
    kg = int(input())
    price = int(input())
    if buttom_stop == 1: 
        if kg_at_least >= kg:
            total += price*(kg-kg_threshhold_previous)
            kg_threshhold_previous = kg #  # Update weight of previous threshhold. 
        elif kg_at_least < kg:
            total += price*(kg_at_least - kg_threshhold_previous)
            buttom_stop = 1  # Calculating stops when buttom_stop = 1.
# Last input of t and r.
threshhold_last = int(input())
price_last = int(input())

if buttom_stop == 1:
    if kg_at_least > threshhold_last:
        total += price_last*(kg_at_least - threshhold_last)
    else:
        total += price_last*(kg_at_least - kg_threshhold_previous)
print(total)

# %%
n = int(input()) 
kg_at_least = int(input())
kg_threshhold_previous = 0
total = 0
rest = kg_at_least

buttom_stop = False

# print("-------------------")
for i in range(n-1):
    kg = int(input())
    price = int(input())
    if buttom_stop == False:
        if kg_at_least >= kg:
    #         print("price:")
    #         print(price*(kg-kg_threshhold_previous))

            total += price*(kg-kg_threshhold_previous)
    #         print("total:")
    #         print(total)

            kg_threshhold_previous = kg
    #         print("kg_threshhold_previous:")
    #         print(kg_threshhold_previous)
    #         print("-------------------")
        elif kg_at_least < kg:
    #         print("price:")
    #         print(price*(kg_at_least - kg_threshhold_previous))
            total += price*(kg_at_least - kg_threshhold_previous)
            buttom_stop = True
        
threshhold_last = int(input())
price_last = int(input())

if buttom_stop == False:
    if kg_at_least > threshhold_last:
        total += price_last*(kg_at_least - threshhold_last)
    #         print("Last added-1!")
    else:
        total += price_last*(kg_at_least - kg_threshhold_previous)
    #         print("Last added-2!")
        
#         print("total:")
#         print(total)
#         print("kg_threshhold_previous:")
#         print(kg_threshhold_previous)
#         print("-------------------")
#     threshhold_last_2 = price

# print("Last input:")
# print("kg_at_least")
# print(kg_at_least)
# print("kg_threshhold_previous")
# print(kg_threshhold_previous)
# print("total:")

print(total)
# Out:
# 3
# 45
# 10
# 55
# 30
# 40
# 1000
# 35
# 1875

# %%
n = int(input()) 
kg_at_least = int(input())
kg_threshhold_previous = 0
total = 0

# print("-------------------")
for i in range(n):
    kg = int(input())
    price = int(input())
    
    if kg_at_least >= kg:
#         print("price:")
#         print(price*(kg-kg_threshhold_previous))
        total += price*(kg-kg_threshhold_previous)
#         print("total:")
#         print(total)

        kg_threshhold_previous = kg
#         print("kg_threshhold_previous:")
#         print(kg_threshhold_previous)
#         print("-------------------")
    elif kg_at_least < kg:
#         print("price:")
#         print(price*(kg_at_least - kg_threshhold_previous))
        total += price*(kg_at_least - kg_threshhold_previous)
#         print("total:")
#         print(total)
#         print("kg_threshhold_previous:")
#         print(kg_threshhold_previous)
#         print("-------------------")
#     threshhold_last_2 = price

# print("Last input:")
# print("kg_at_least")
# print(kg_at_least)
# print("kg_threshhold_previous")
# print(kg_threshhold_previous)
# print("total:")

print(total)

# %%
n = int(input()) 
kg_at_least = int(input())
kg_threshhold_previous = 0
total = 0
rest_kg = kg_at_least
rest_kg = rest_kg - kg_threshhold_previous    

# print("-------------------")
for i in range(n-1):
    kg_threshhold = int(input())
    price = int(input())
    
#     print("rest_kg:")
#     print(rest_kg)
#     print("kg_at_least:")
#     print(kg_at_least)
    
    if kg_at_least >= kg_threshhold:
#         print("price:")
#         print(price*(kg_threshhold - kg_threshhold_previous))
        total += price*(kg_threshhold - kg_threshhold_previous)
#         print("total:")
#         print(total)


        kg_threshhold_previous = kg_threshhold
#         print("kg_threshhold_previous:")
#         print(kg_threshhold_previous)

        rest_kg -= kg_threshhold_previous
#         print("rest_kg:")
#         print(rest_kg)


    elif kg_at_least < kg_threshhold:
        if rest_kg > 0:
#             print("rest_kg:")
#             print(rest_kg)
#             print("kg_at_least:")
#             print(kg_at_least)
            total += price*(rest_kg - kg_threshhold_previous)
#             print("total:")
#             print(total)
#     print("rest_kg:")
#     print(rest_kg)
#     print("kg_at_least:")
#     print(kg_at_least)
#     print("total:")
#     print(total)
#     print("-------------------")
threshhold_last = int(input())
price_last = int(input())

if kg_at_least >threshhold_last:
    if rest_kg > 0:
        total += price_last*(threshhold_last - kg_threshhold_previous)
#         print("Last added-1!")
else:
    if rest_kg > 0:
#         print("price last:")
#         print(price_last*(kg_at_least - kg_threshhold_previous))
        total += price_last*(kg_at_least - kg_threshhold_previous)
#         print("Last added-2!")

# print("Last input:")
# print("kg_at_least")
# print(kg_at_least)
# print("kg_threshhold_previous")
# print(kg_threshhold_previous)
# print("rest_kg:")
# print(rest_kg)
# print("kg_at_least:")
# print(kg_at_least)
# print("total:")
# print(total)

print(total)

# %%
""
n = int(input()) 
kg_at_least = int(input())
kg_threshhold_previous = 0
total = 0

# print("-------------------")
for i in range(n-1):
    kg = int(input())
    price = int(input())
    
    if kg_at_least >= kg:
#         print("price:")
#         print(price*(kg-kg_threshhold_previous))
        total += price*(kg-kg_threshhold_previous)
#         print("total:")
#         print(total)
        kg_threshhold_previous = kg
#         print("kg_threshhold_previous:")
#         print(kg_threshhold_previous)
#         print("-------------------")
#     kg_threshhold_previous = kg
    elif kg_at_least < kg:
        total += price*(kg_at_least)
        kg_threshhold_previous = kg

# print("Last input:")
# print("kg_at_least")
# print(kg_at_least)
# print("kg_threshhold_previous")
# print(kg_threshhold_previous)
# print("total:")
# print(total)

# print("-------------------")

threshhold_last = int(input())
price_last = int(input())

if kg_at_least>=threshhold_last:
    total += price_last*((kg_at_least-threshhold_last)-kg_threshhold_previous)
#     total += price_last*(kg_at_least-threshhold_last)

elif kg_at_least<threshhold_last:
#     print("price_last*(kg_at_least-kg_threshhold_previous):")
#     print(price_last*(kg_at_least-kg_threshhold_previous))
    if kg_at_least >= kg_threshhold_previous:
        total += price_last*(kg_at_least-kg_threshhold_previous)
# print("-------------------")
# print("Last input:")
# print("kg_at_least")
# print(kg_at_least)
# print("kg_threshhold_previous")
# print(kg_threshhold_previous)
# print("total:")
# print(total)
# print("-------------------")
print(total)
