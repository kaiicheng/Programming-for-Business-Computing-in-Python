# %%
# Store all inputs.
line_one = input()
line_two = input()
line_three = input()

# Split inputs and store in respective space.
line_one = line_one.split(",")
number_of_investment = int(line_one[0])  # number_of_item is n.
budget = int(line_one[1])  # Budget.
risk_coefficient = int(line_one[2])  # Risk coefficient.
capital_needs = line_two.split(",")  # The capital needed if invest it.
expected_return = line_three.split(",")  # Expected gain if invest it.

# Store the information of variance and covariance in the matrix.
matrix = []
for i in range(number_of_investment):
    line = input()
    line = line.split(",")
    temp = []
    for j in range(len(line)):
        temp.append(int(line[j]))
    matrix.append(temp)

# Create a list to store all index.
index_list = []
for i in range(number_of_investment):
    index_list.append(i+1)

# Create a list to store total_target_list(capital_needs,
# expected_return, index).
total_target_list = []
for i in range(number_of_investment):
    list_temp = []
    list_temp.append(int(capital_needs[i]))
    list_temp.append(int(expected_return[i]))
    list_temp.append(i+1)
    total_target_list.append(list_temp)

# Create answer_list_one to store index of choosen items.
answer_list = []
total = 0  # Space to store total revenue.
target_list = []  # Space to store all targeted element.
for i in range(number_of_investment):  # Run for n times.
    target_list = []  # Space to store all targeted element.
    for j in range(len(index_list)):

        # Create a list needed in n round.
        list_n_round_needed = []
        for k in range(len(index_list)):
            for l in range(len(total_target_list)):
                if index_list[k] == total_target_list[l][2]:
                    list_n_round_needed.append(total_target_list[l])
                    list_n_round_needed.append(total_target_list[l][])

        # Calculate total revenue with the formulation.
        if i == 0:  # Situation when calculate first time.
            answer = int(expected_return[j])-risk_coefficient*(matrix[j][j])
        elif i != 0:  # Situation when calculate except first time.
            reference = index_list[j] - 1
            minus = risk_coefficient*matrix[reference][reference]
            minus = minus + matrix[previous_number][j]
            minus = minus + matrix[j][previous_number]
            answer = int(expected_return[reference]) - minus

        # Create a sublist to store the information of element.
        lst = []
        lst.append(answer)
        lst.append(list_n_round_needed[j][2])
        lst.append(int(capital_needs[j]))
        target_list.append(lst)  # Append the sublist in the target_list.
    # Compare max reveue choice whih other choices.
    target_list.sort()
    target_list.reverse()
    revenue = target_list[0][0]
    capital = target_list[0][2]
    index = target_list[0][1]

    # Compare the choosen item with other items.
    for j in range(len(target_list)):
        if revenue == target_list[j][0]:
            # Situation when two items with same revenue value.
            if capital == target_list[j][2]:
                # Situation when two items with same capital needed.
                if index > target_list[j][1]:
                    # Pick the item with smaller index.
                    revenue = target_list[j][0]
                    capital = target_list[j][2]
                    index = target_list[j][1]
            elif capital > target_list[j][2]:
                    # Pick the item with smaller capital needed.
                    revenue = target_list[j][0]
                    capital = target_list[j][2]
                    index = target_list[j][1]
    # Remove the chosen index from the index_list.
    index_list.remove(index)
    # Store the chosen index.
    previous_number = index - 1

    # Situation when the revenue is over 0.
    if revenue > 0:
        # Situation if the (budget - capital) needed isn't over budget.
        if budget - capital >= 0:
            total += target_list[0][0]  # Calculate total.
            budget -= capital  # Deduct capital needed from the budget.
            answer_list.append(index)  # Add the chose element.
answer_list.sort()  # Sort answer_list.

# Print result.
if len(answer_list) > 0:
    # Situation when the answer_list isn't empty.
    for i in range(len(answer_list)):
        if i == len(answer_list)-1:
            print(answer_list[i], end="")
        else:
            print(answer_list[i], end="")
            print(",", end="")
elif len(answer_list) == 0:
    # Situation when the answer_list is empty.
    print(0)
# Out:
# 4,15,1
# 8,7,5,4
# 20,30,40,35
# 10,4,-3,-9
# 4,8,-2,-3
# -3,-2,11,4
# -9,-3,4,3
# total_target_list(capital_needs, expected_return, index):
# total_target_list(capital_needs, expected_return, index):
# total_target_list(capital_needs, expected_return, index):
# total_target_list(capital_needs, expected_return, index):
# 2,4

# %%
# 12/25 12:00
# line_one = input()
# line_two = input()
# line_three = input()

# input 1
line_one = "4,15,1"
line_two = "8,7,5,4"
line_three = "20,30,40,35"

# input2
# line_one = "4,8,10"
# line_two = "8,7,5,4"
# line_three = "2,3,4,3"

line_one = line_one.split(",")
number_of_investment = int(line_one[0])
budget = int(line_one[1])
risk_coefficient = int(line_one[2])
capital_needs = line_two.split(",")
expected_return = line_three.split(",")

matrix = []
for i in range(number_of_investment):
    line = input()
    line = line.split(",")
    temp = []
    for j in range(len(line )):
        temp.append(int(line[j]))
    matrix.append(temp)

capital_needs_list = []
for i in range(number_of_investment):
    lst = []
    lst.append(i+1)
    lst.append(int(capital_needs[i]))
    capital_needs_list.append(lst)
# print("capital_needs_list:", capital_needs_list)
# print("number_of_investment:",number_of_investment)
# print("budget:",budget)
# print("risk_coefficient:",risk_coefficient)
# print("capital_needs:",capital_needs)
# print("expected_return:",expected_return)
# print("matrix:",matrix)

# Create a list to store all index.
index_list = []
for i in range(number_of_investment):
    index_list.append(i+1)
print("index_list:", index_list)

# Create a list to store total_target_list(capital_needs, expected_return, index).
total_target_list = []
for i in range(number_of_investment):
    list_temp = []
    list_temp.append(int(capital_needs[i]))
    list_temp.append(int(expected_return[i]))
    list_temp.append(i+1)
    total_target_list.append(list_temp)
print("total_target_list:",total_target_list)

total = []
first_time = True
target_list = []
target_list_copy = []
print("-----------------")
for i in range(number_of_investment):
    target_list = []
    for j in range(len(index_list)):
        print("i:", i)
        print("j:", j)
        list_n_round_needed = []
        for k in range(len(index_list)):
            for l in range(len(total_target_list)):
                if index_list[k] == total_target_list[l][2]:
                    list_n_round_needed.append(total_target_list[l])
        print("total_target_list(capital_needs, expected_return, index):")
        print("list_n_round_needed:",list_n_round_needed)
#         print("target_list(list(max revenue, index,capital_needed,)):",target_list)
#         if i == 0:
#             number_one = j
#             previous_number = 0
#             number_two = previous_number
#         else:
#             number_one = j
#             number_two = previous_number
        if i == 0:
            answer = int(expected_return[j])-risk_coefficient*(matrix[j][j])
            print("answer:",answer)
        elif i != 0:
            print("index_list[j]:", index_list[j])
            reference = index_list[j] - 1
#             print("matrix[reference][reference]:",matrix[reference][reference])
            minus = risk_coefficient*matrix[reference][reference]
#             print("(matrix[previous_number][j] + matrix[j][previous_number]):", (matrix[previous_number][j] + matrix[j][previous_number]))
            minus = minus + matrix[previous_number][j] + matrix[j][previous_number]
#             print("minus:", minus)
#             print("int(expected_return[reference]):", int(expected_return[reference]))
            answer = int(expected_return[reference]) - minus
            print("answer:",answer)
        lst = []
        lst.append(answer)
        lst.append(list_n_round_needed[j][2])
        lst.append(int(capital_needs[j]))
        target_list.append(lst)
        print("-----------------")
#     if i == 0:
#         for k in range(len(target_list)):
#             target_list_copy.append(target_list[k])
    print("target_list(list(max revenue, index,capital_needed,)):",target_list)
    print("-----------------")
    target_list.sort()
    target_list.reverse()
    print("target_list(sorted)",target_list)
    index = target_list[0][1]  # 4
    print("index:",index)
    index_list.remove(index)
    print("index_list:", index_list)
    previous_number = index - 1
    print("previous_number:",previous_number)
    target_list = []
    print("-----------------")

"""
    print("target_list:",target_list)
    target_list.sort()
    target_list.reverse()
    print("targer_list(sorted)",target_list)

    index = target_list[0][1]  # 4
    index_list.remove(index)
    print("index_list:", index_list)
"""
    
# input1
#    10,4,-3,-9
#    4,8,-2,-3
#    -3,-2,11,4
#    -9,-3,4,3

# input2
#    10,4,-3,-9
#    4,8,-2,-3
#    -3,-2,11,4
#    -9,-3,4,3
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-63b2ed150896> in <module>
#      23 matrix = []
#      24 for i in range(number_of_investment):
# ---> 25     line = input()
#      26     line = line.split(",")
#      27     temp = []
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
# 10/25 11:00

# line_one = input()
# line_two = input()
# line_three = input()

# input 1
line_one = "4,15,1"
line_two = "8,7,5,4"
line_three = "20,30,40,35"

# input2
# line_one = "4,8,10"
# line_two = "8,7,5,4"
# line_three = "2,3,4,3"

line_one = line_one.split(",")
number_of_investment = int(line_one[0])
budget = int(line_one[1])
risk_coefficient = int(line_one[2])
capital_needs = line_two.split(",")
expected_return = line_three.split(",")

matrix = []
for i in range(number_of_investment):
    line = input()
    line = line.split(",")
    temp = []
    for j in range(len(line )):
        temp.append(int(line[j]))
    matrix.append(temp)

capital_needs_list = []
for i in range(number_of_investment):
    lst = []
    lst.append(i+1)
    lst.append(int(capital_needs[i]))
    capital_needs_list.append(lst)
# print("capital_needs_list:", capital_needs_list)
# print("number_of_investment:",number_of_investment)
# print("budget:",budget)
# print("risk_coefficient:",risk_coefficient)
# print("capital_needs:",capital_needs)
# print("expected_return:",expected_return)
# print("matrix:",matrix)

# Create a list to store all index.
index_list = []
for i in range(number_of_investment):
    index_list.append(i+1)
print("index_list:", index_list)

# Create a list to store sublist(capital_needs, expected_return, index).
total_target_list = []
for i in range(number_of_investment):
    list_temp = []
    list_temp.append(int(capital_needs[i]))
    list_temp.append(int(expected_return[i]))
    list_temp.append(i+1)
    total_target_list.append(list_temp)
print("total_target_list:",total_target_list)

total = []
first_time = True
target_list = []
target_list_copy = []
print("-----------------")
for i in range(number_of_investment):
    print("i:", i)
    for j in range(len(index_list)):
#         print("target_list(sorted)",target_list)
        covariance = 0
        print("j:", j)
        
#         # Create a list of index we need.
#         lst = []
#         for k in range(len(index_list)):
#             lst.append(index_list[k])
#         print("lst:",lst)
        
        list_n_round_needed = []
        for k in range(len(index_list)):
            for l in range(len(total_target_list)):
                if index_list[k] == total_target_list[l][2]:
                    list_n_round_needed.append(total_target_list[l])
        print("list_n_round_needed:",list_n_round_needed)
        
        if i == 0:
            number_one = j
            previous_number = 0
            number_two = previous_number
        else:
            number_one = j
            number_two = previous_number
        if i == 0:
            answer = int(expected_return[j])-risk_coefficient*(matrix[j][j])
            print("answer:",answer)
        elif i != 0:
            print("index_list[j]:", index_list[j])
            reference = index_list[j] - 1
#             print("matrix[reference][reference]:",matrix[reference][reference])
            minus = risk_coefficient*matrix[reference][reference]
#             print("(matrix[previous_number][j] + matrix[j][previous_number]):", (matrix[previous_number][j] + matrix[j][previous_number]))
            minus = minus + matrix[previous_number][j] + matrix[j][previous_number]
#             covariancei = 
#             print("minus:", minus)
#             print("int(expected_return[reference]):", int(expected_return[reference]))
            answer = int(expected_return[reference]) - minus
        print("answer:",answer)


        lst = []
        lst.append(answer)
        lst.append(j+1)
        lst.append(int(capital_needs[j]))
        target_list.append(lst)
#         print("target_list:",target_list)
#         print("-----------------")
    if i == 0:
        for k in range(len(target_list)):
            target_list_copy.append(target_list[k])
    print("target_list(list(max revenue, index,capital_needed,)):",target_list)
    print("-----------------")
    target_list.sort()
    target_list.reverse()
    print("target_list(sorted)",target_list)
    index = target_list[0][1]  # 4
    print("index:",index)
    index_list.remove(index)
    
    print("index_list:", index_list)
    previous_number = index - 1
    print("previous_number:",previous_number)
    target_list = []
    print("-----------------")

"""
    print("target_list:",target_list)
    target_list.sort()
    target_list.reverse()
    print("targer_list(sorted)",target_list)

    index = target_list[0][1]  # 4
    index_list.remove(index)
    print("index_list:", index_list)
"""
    
# input1
#    10,4,-3,-9
#    4,8,-2,-3
#    -3,-2,11,4
#    -9,-3,4,3

# input2
#    10,4,-3,-9
#    4,8,-2,-3
#    -3,-2,11,4
#    -9,-3,4,3

# %%
print("number_of_investment:",number_of_investment)

# %%
print("matrix:",matrix)

# %%
for i in range(-1):
    print(1)
