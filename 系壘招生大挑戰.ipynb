# %%
# Store inputs by each line.
first_line = input()
second_line = input()
third_line = input()
fourth_line = input()
# Split with ",".
second_line = second_line.split(",")
price_list = third_line.split(",")
number_list = fourth_line.split(",")
# Variable kind is how many kind of equipment the store provides.
kind = int(first_line)

# Store all numbers of products are in set.
set_product_list = []
for n in range(len(second_line)):
    set_product_list.append(int(second_line[n]))

# Store the ordinal number of products are in set.
ordinal_set_product_list = []
for n in range(len(set_product_list)):
    ordinal_set_product_list.append(set_product_list[n]-1)

# Store of each number of products in set we need to purchase.
number_of_set_product = []
for n in range(len(set_product_list)):
    number_one = int(number_list[int(ordinal_set_product_list[n])])
    number_of_set_product.append(number_one)

# Find the minimun of set.
min_number_set_product_list = number_of_set_product
min_number_set_product_list.sort()
min_number_of_set_product = int(min_number_set_product_list[0])

# Calculate the price without discount and store in original_price.
original_price = 0
for n in range(kind):
    original_price += int(price_list[n])*int(number_list[n])

# Calculate how many 5 sets we'll buy and how many set left.
five_sets = 0
not_five_set = 0
if min_number_of_set_product < 5:  # Situation when sets is less than 5.
    five_sets = 0
    not_five_set = min_number_of_set_product
else:   # Situation when sets is more than 5.
    if min_number_of_set_product < 10:  # Situation when sets is less than 10.
        five_sets = 1
        not_five_set = min_number_of_set_product - 5
    else:
        # Situation when sets is more than 10.
        # Calculate how many 5 sets we'll buy and how many set left.
        while min_number_of_set_product >= 5:
            five_sets += 1
            min_number_of_set_product = min_number_of_set_product-5
            not_five_set = min_number_of_set_product

# Sum up price of sets of products, and store it in total.
total = 0
# List to store number products deducted by number of discounted products.
number_of_rest_product_list = number_list
for i in range(len(ordinal_set_product_list)):
    total += int(price_list[ordinal_set_product_list[i]])*five_sets*5*0.8
    total += int(price_list[ordinal_set_product_list[i]])*not_five_set*1*0.9
    number_two = int(number_list[ordinal_set_product_list[i]])
    rest_number = number_two-5*five_sets-not_five_set
    total += int(price_list[ordinal_set_product_list[i]])*rest_number
    number_two = number_of_rest_product_list[ordinal_set_product_list[i]]
    original_number = int(number_two)
    number_of_rest_product_list[int(ordinal_set_product_list[i])] = 0

# Sum up the prices of products which is not discounted.
for j in range(len(number_of_rest_product_list)):
    total += int(price_list[j])*int(number_of_rest_product_list[j])

# Calculate how many players we can hire.
number_of_player = int((original_price - total)/1000)
total = int(total)

# Determine whether we are able to hire new player or not.
if number_of_player > 0:
    print(str(total) + ",", end="")
    print(number_of_player)
else:
    print("So sad. I messed up.")
# Out:
# 4
# 1,4
# 600,250,500,300
# 4,2,1,0
# So sad. I messed up.

# %%
print(10%5)

# %%
print(int(17%5))

# %%
# Store inputs by each line.
first_line = input()
second_line = input()
third_line = input()
fourth_line = input()
# Split with ",".
second_line = second_line.split(",")
price_list = third_line.split(",")
number_list = fourth_line.split(",")
# Variable kind is how many kind of equipment the store provides.
kind = int(first_line)

# Store all numbers of products are in set.
set_product_list = []
for n in range(len(second_line)):
    set_product_list.append(int(second_line[n]))

# Store the ordinal number of products are in set.
ordinal_set_product_list = []
for n in range(len(set_product_list)):
    ordinal_set_product_list.append(set_product_list[n]-1)

# Store of each number of products in set we need to purchase. 
number_of_set_product = []
for n in range(len(set_product_list)):
    number_of_set_product.append(int(number_list[int(ordinal_set_product_list[n])]))

# Find the minimun of set.
min_number_set_product_list = number_of_set_product
min_number_set_product_list.sort()
min_number_of_set_product = int(min_number_set_product_list[0])

# Calculate the price without discount and store in original_price.
original_price = 0
for n in range(kind):
    original_price += int(price_list[n])*int(number_list[n])

# Calculate how many 5 sets we'll buy and how many set left.
five_sets = 0
not_five_set = 0#*****
if min_number_of_set_product < 5:  # Situation when sets is less than 5.
    five_sets = 0
    not_five_set = min_number_of_set_product
else:   # Situation when sets is more than 5.
    if min_number_of_set_product < 10:  # Situation when sets is less than 10.
        five_sets = 1
        not_five_set = min_number_of_set_product - 5
    else:
        # Situation when sets is more than 10.
        # Calculate how many 5 sets we'll buy and how many set left.
        while min_number_of_set_product >= 5:  
            five_sets += 1
            min_number_of_set_product = min_number_of_set_product-5
            not_five_set = min_number_of_set_product

# Sum up price of set of products.
total = 0
number_of_rest_product_list = number_list
for i in range(len(ordinal_set_product_list)):
#     print(i)
#     print("if")
#     print(ordinal_set_product_list[i])
#     print(int(price_list[ordinal_set_product_list[i]]))
#     print(int(number_list[ordinal_set_product_list[i]]))
#     print(int(price_list[ordinal_set_product_list[i]])*five_sets*5*0.8)
    total += int(price_list[ordinal_set_product_list[i]])*five_sets*5*0.8
#     print(int(price_list[ordinal_set_product_list[i]])*not_five_set*1*0.9)
    total += int(price_list[ordinal_set_product_list[i]])*not_five_set*1*0.9
    rest_number = int(number_list[ordinal_set_product_list[i]])-5*five_sets-not_five_set
#     print(int(price_list[ordinal_set_product_list[i]])*rest_number)
    total += int(price_list[ordinal_set_product_list[i]])*rest_number
#     print(total)
#     print("number_of_rest_product_list:")
#     print(number_of_rest_product_list)
    original_number = int(number_of_rest_product_list[ordinal_set_product_list[i]])
#     print(original_number)
#     number_of_rest_product_list(int(price_list[ordinal_set_product_list[i]])) = original_number - five_sets*5 - not_five_set - rest_number
    number_of_rest_product_list[int(ordinal_set_product_list[i])] = 0
#     print("---------------------")
# print("number_of_rest_product_list:")
# print(number_of_rest_product_list)

for j in range(len(number_of_rest_product_list)):
#     print("else:")
#     print(int(price_list[j])*int(number_of_rest_product_list[j]))
    total += int(price_list[j])*int(number_of_rest_product_list[j])
#     print(total)
# print("---------------------")

# print(number_of_set_product)
# print(set_product_list)
# print("---------------------")
# print(total)

number_of_player = int((original_price - total)/1000)
# print(number_of_player)
total = int(total)

if number_of_player > 0:
    print(str(total) + ",", end = "") 
    print(number_of_player)
else:
    print("So sad. I messed up.")

# %%
first_line = input()
second_line = input()
third_line = input()
fourth_line = input()

second_line = second_line.split(",")
third_line = third_line.split(",")
fourth_line = fourth_line.split(",")

print(first_line)
print(second_line)
print(third_line)
print(fourth_line)

price_list = third_line
number_list = fourth_line

kind = int(first_line)
set_product = []
for n in range(len(second_line)):
    set_product.append(int(second_line[n]))
print("set_product:")
print(set_product)

number_set_product = []
for n in range(len(set_product)):
    print(set_product[n])
    print(int(number_list[set_product[n]-1]))
    number_set_product.append(int(number_list[set_product[n]-1]))
print("number_set_product:")
print(number_set_product)

print("len(set_product):")
print(len(set_product))
number_set_product.sort()
print("number_set_product:")
print(number_set_product)
min_number_set_product = int(number_set_product[0])
print("min_number_set_product:")
print(min_number_set_product)

price_1 = int(third_line[0])
price_2 = int(third_line[1])
price_3 = int(third_line[2])
price_4 = int(third_line[3])

number_1 = int(fourth_line[0])
number_2 = int(fourth_line[1])
number_3 = int(fourth_line[2])
number_4 = int(fourth_line[3])

original_price = price_1*number_1 + price_2*number_2 + price_3*number_3 + price_4*number_4
print("original_price:")
print(original_price)

if min_number_set_product < 5:
    number_of_5_sets = 0
    number_rest_product = min_number_set_product
else:
    number_of_5_sets = int(min_number_set_product/5)
    number_rest_product = min_number_set_product//5
print(number_of_5_sets)
print(number_rest_product)
    
print("---------------------")
print("set_product:")
print(set_product)
total = 0
# number_set_product[i] = int(number_set_product[i] - 5*number_of_5_sets)
# number_set_product[i] = int(number_set_product[i] - number_rest_product)

new_set_product = []
for n in range(len(set_product)):
    new_set_product.append(set_product[n]-1)
print("new_set_product:")
print(new_set_product)

for i in range(len(number_list)):
    print(i)
    print(set_product)
    print(price_list)
    
    if i in new_set_product:
        print("if")
        print(int(price_list[new_set_product[i-1]]))
        print(int(price_list[new_set_product[i-1]])*number_of_5_sets*5*0.8)
        total += int(price_list[new_set_product[i-1]])*number_of_5_sets*5*0.8
        print(int(price_list[new_set_product[i-1]])*number_rest_product*1*0.9)
        total += int(price_list[new_set_product[i-1]])*number_rest_product*1*0.9
        print(int(price_list[new_set_product[i-1]])*(int(number_list[new_set_product[i-1]])-5*number_of_5_sets-number_rest_product))
        total += int(price_list[new_set_product[i-1]])*(int(number_list[new_set_product[i-1]])-5*number_of_5_sets-number_rest_product)
        print(total)
    else:
        print("else:")
        print(int(price_list[i])*int(number_list[i]))
        total += int(price_list[i])*int(number_list[i])
    print("---------------------")

print(number_set_product)
print(set_product)
print("---------------------")
print(total)

number_of_player = int((original_price - total)/1000)
print(number_of_player)
total = int(total)

if number_of_player > 0:
    print(str(total) + ",", end = "") 
    print(number_of_player)
else:
    print("So sad. I messed up.")
