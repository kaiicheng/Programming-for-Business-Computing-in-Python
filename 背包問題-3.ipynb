# %%
# Store all inputs.
line_one = input()
line_two = input()
line_three = input()

# Split inputs and store in respective space.
line_one = line_one.split(",")
number_of_item = int(line_one[0])  # number_of_item is n.
upper_limit = int(line_one[1])  # upper_limit is B.
weight_list = line_two.split(",")  # List with numbers of weight.
utility_list = line_three.split(",")  # List with numbers of utility.

# Method 1
method_one_list = []
# Store sublists into another list.
for i in range(number_of_item):
    # Create a list with (cp value, weight, utility, numebr(from 1 to n)).
    lst = []
    lst.append(int(utility_list[i])/int(weight_list[i]))
    lst.append(int(weight_list[i]))
    lst.append(int(utility_list[i]))
    lst.append(i+1)
    lst.append(0)
    # Store the lst into method_one_list.
    method_one_list.append(lst)

# Copy the method_one_list.
method_one_list_copy = []
for i in range(len(method_one_list)):
    method_one_list_copy.append(method_one_list[i])
# Sort and then reverse the method_one_list.
method_one_list.sort()
method_one_list.reverse()

# Create spaces to store data of total weight, cp value and utility.
total_weight_one = 0
total_cp_value_one = 0
total_utility_one = 0

# Create answer_list_one to store index of choosen items.
answer_list_one = []
for i in range(number_of_item):
    for j in range(len(method_one_list)):
        # Mark every element as unread.
        method_one_list[j][4] = 0
    if total_weight_one + int(method_one_list[i][1]) <= upper_limit:
        # Situation when total weight is less than or equal to upper_limit.
        # Calaulate total cp value, weight and utility.
        if method_one_list[i][4] == 0:
            # Situation when the item is unread.
            # Calculate total cp value, weight and utility.
            total_cp_value_one += method_one_list[i][0]
            total_weight_one += int(method_one_list[i][1])
            total_utility_one += method_one_list[i][2]

            # Store index, cp value, weight and minimal number of items.
            index = method_one_list[i][3]
            max_cp_value = method_one_list_copy[index-1][0]
            min_weight = method_one_list_copy[index-1][1]
            min_number = method_one_list_copy[index-1][3]

            # Compare the choosen item with other items.
            for j in range(len(method_one_list)):
                if max_cp_value == method_one_list[j][0]:
                    # Situation when two items with same cp value.
                    if min_weight == method_one_list[j][1]:
                        # Situation when two items with same weight.
                        if min_number > method_one_list[j][3]:
                            # Pick the item with smaller number.
                            min_number = method_one_list[j][3]
                            index = method_one_list[j][3]
                    elif min_weight > method_one_list[j][1]:
                        # Pick the item with smaller weight.
                        min_weight = method_one_list[j][1]
                        index = method_one_list[j][3]
            # Mark the chosen item as read.
            for j in range(len(method_one_list)):
                if method_one_list[j][3] == index:
                    method_one_list[j][4] = 1
            # Add the chose item to the answer_list_one.
            answer_list_one.append(index)
answer_list_one.sort()  # Sort answer_list_one.

# Situation when the list is empty.
if len(answer_list_one) == 0:
    answer_list_one.append(0)

# Method 2
method_two_list = []  # Create a list to store answer element.
for i in range(number_of_item):  # Check every item.
    # Create a list with (utility, weight, numebr(from 1 to n))
    lst = []
    lst.append(int(utility_list[i]))
    lst.append(int(weight_list[i]))
    lst.append(i+1)
    method_two_list.append(lst)  # Store lst in method_two_list.

# Sort and reverse method_two_list.
method_two_list.sort()
method_two_list.reverse()

total_weight_two = 0  # Space to store total weight.
total_utility_two = 0  # Space to store total utility.
answer_list_two = []  # Create a list to store answer element.

# Check every item and calculate total weight and utility.
for i in range(len(method_two_list)):
    # list with (utility, weight, numebr(from 1 to n))
    if total_weight_two + int(method_two_list[i][1]) <= upper_limit:
        # Situation when total_weight is smaller than or equal to upper_limit.
        total_utility_two += int(method_two_list[i][0])
        total_weight_two += int(method_two_list[i][1])
        answer_list_two.append(method_two_list[i][2])
answer_list_two.sort()  # Sort answer_list_two.

if len(answer_list_two) == 0:  # Situation when the list is empty.
    answer_list_two.append(0)

# Compare total utilities of two methods, and print result.
if total_utility_one > total_utility_two:
    for i in range(len(answer_list_one)):
        # Choose method one.
        if i == len(answer_list_one)-1:
            print(answer_list_one[i], end="")
        else:
            print(answer_list_one[i], end="")
            print(",", end="")
elif total_utility_one < total_utility_two:
    for i in range(len(answer_list_two)):
        # Choose method two.
        if i == len(answer_list_two)-1:
            print(answer_list_two[i], end="")
        else:
            print(answer_list_two[i], end="")
            print(",", end="")
elif total_utility_one == total_utility_two:
    for i in range(len(answer_list_two)):
        # Choose method two.
        if i == len(answer_list_two)-1:
            print(answer_list_two[i], end="")
        else:
            print(answer_list_two[i], end="")
            print(",", end="")

# %%
# Store all inputs.
line_one = input()
line_two = input()
line_three = input()

# Split inputs and store in respective space.
line_one = line_one.split(",")
number_of_item = int(line_one[0])  # number_of_item is n.
upper_limit = int(line_one[1])  # upper_limit is B.
weight_list = line_two.split(",")  # List with numbers of weight.
utility_list = line_three.split(",")  # List with numbers of utility.

# Method 1
method_one_list = []
# Store sublists into another list.
for i in range(number_of_item):
    # Create a list with (cp value, weight, utility, numebr(from 1 to n)).
    lst = []
    lst.append(int(utility_list[i])/int(weight_list[i]))
    lst.append(int(weight_list[i]))
    lst.append(int(utility_list[i]))
    lst.append(i+1)
    lst.append(0)
    # Store the lst into method_one_list.
    method_one_list.append(lst)

# Copy the method_one_list.
method_one_list_copy = []
for i in range(len(method_one_list)):
    method_one_list_copy.append(method_one_list[i])
# Sort and then reverse the method_one_list.
method_one_list.sort()
method_one_list.reverse()

# Create spaces to store data of total weight, cp value and utility.
total_weight_one = 0
total_cp_value_one = 0
total_utility_one = 0

# Create answer_list_one to store index of choosen items.
answer_list_one = []
for i in range(number_of_item):
    for j in range(number_of_item):
        # Mark every element as unread.
        method_one_list[j][4] = 0
    if total_weight_one + int(method_one_list[i][1]) <= upper_limit:
        # Situation when total weight is less than or equal to upper_limit.
        # Calaulate total cp value, weight and utility.
        if method_one_list[i][4] == 0:
            # Situation when the item is unread.
            # Calculate total cp value, weight and utility.
            total_cp_value_one += method_one_list[i][0]
            total_weight_one += int(method_one_list[i][1])
            total_utility_one += method_one_list[i][2]

            # Store index, cp value, weight and minimal number of items.
            index = method_one_list[i][3]
            max_cp_value = method_one_list_copy[index-1][0]
            min_weight = method_one_list_copy[index-1][1]
            min_number = method_one_list_copy[index-1][3]

            # Compare the choosen item and compare with other items.
            for j in range(len(method_one_list)):
                if max_cp_value == method_one_list[j][0]:
                    # Situation when two items with same cp value.
                    if min_weight == method_one_list[j][1]:
                        # Situation when two items with same weight.
                        if min_number > method_one_list[j][3]:
                            # Pick the item with smaller number.
                            min_number = method_one_list[j][3]
                            index = method_one_list[j][3]
                            # Mark the item as read.
                            method_one_list[j][4] = 1
                    elif min_weight > method_one_list[j][1]:
                        # Pick the item with smaller number.
                        min_weight = method_one_list[j][1]
                        index = method_one_list[j][3]
                        # Mark the item as read.
                        method_one_list[j][4] = 1
            # Store all indeces of chosen number.
            answer_list_one.append(index)
answer_list_one.sort()  # Sort answer_list_one.

# Situation when the list is empty.
if len(answer_list_one) == 0:
    answer_list_one.append(0)

# Method 2
method_two_list = []  # Create a list to store answer element.
for i in range(number_of_item):  # Check every item.
    # Create a list with (utility, weight, numebr(from 1 to n))
    lst = []
    lst.append(int(utility_list[i]))
    lst.append(int(weight_list[i]))
    lst.append(i+1)
    method_two_list.append(lst)  # Store lst in method_two_list.

# Sort and reverse method_two_list.
method_two_list.sort()
method_two_list.reverse()

total_weight_two = 0  # Space to store total weight.
total_utility_two = 0  # Space to store total utility.
answer_list_two = []  # Create a list to store answer element.

# Check every item and calculate total weight and utility.
for i in range(len(method_two_list)):
    # list with (utility, weight, numebr(from 1 to n))
    if total_weight_two + int(method_two_list[i][1]) <= upper_limit:
        # Situation when total_weight is smaller than or equal to upper_limit.
        total_utility_two += int(method_two_list[i][0])
        total_weight_two += int(method_two_list[i][1])
        answer_list_two.append(method_two_list[i][2])
answer_list_two.sort()  # Sort answer_list_two.

if len(answer_list_two) == 0:  # Situation when the list is empty.
    answer_list_two.append(0)

# Compare total utilities of two methods.
if total_utility_one > total_utility_two:
    for i in range(len(answer_list_one)):
        # Choose method one.
        if i == len(answer_list_one)-1:
            print(answer_list_one[i], end="")
        else:
            print(answer_list_one[i], end="")
            print(",", end="")
elif total_utility_one < total_utility_two:
    for i in range(len(answer_list_two)):
        # Choose method two.
        if i == len(answer_list_two)-1:
            print(answer_list_two[i], end="")
        else:
            print(answer_list_two[i], end="")
            print(",", end="")
elif total_utility_one == total_utility_two:
    for i in range(len(answer_list_two)):
        # Choose method two.
        if i == len(answer_list_two)-1:
            print(answer_list_two[i], end="")
        else:
            print(answer_list_two[i], end="")
            print(",", end="")

# %%
# Store all inputs.
line_one = input()
line_two = input()
line_three = input()

# Split inputs and store in respective space.
line_one = line_one.split(",")
number_of_item = int(line_one[0])  # number_of_item is n.
upper_limit = int(line_one[1])  # upper_limit is B.
weight_list = line_two.split(",")  # List with numbers of weight.
utility_list = line_three.split(",")  # List with numbers of utility.

# Method 1
method_one_list = []
# Store sublists into another list. 
for i in range(number_of_item):
    # Create a list with (cp value, weight, utility, 
    # numebr(from 1 to n), 0 (1 means read, 0 mean unread)).
    lst = []
    lst.append(int(utility_list[i])/int(weight_list[i]))
    lst.append(int(weight_list[i]))
    lst.append(int(utility_list[i]))
    lst.append(i+1)  # Label items from 1 to n.
    lst.append(0)
    
    # Store the lst in method_one_list.
    method_one_list.append(lst)

# Copy the method_one_list.
method_one_list_copy = []
for i in range(len(method_one_list)):
    method_one_list_copy.append(method_one_list[i])
# Sort and then reverse the method_one_list.
method_one_list.sort()
method_one_list.reverse()

# Create spaces to store data of total weight, cp value and utility.
total_weight_one = 0
total_cp_value_one = 0
total_utility_one = 0

# Create answer_list_one to store index of choosen items.
answer_list_one = []
for i in range(number_of_item):
    for j in range(number_of_item):
        # Mark every element as unread.
        method_one_list[j][4] = 0
    if total_weight_one + int(method_one_list[i][1]) <= upper_limit:
        # Situation when total weight is less than or equal to upper_limit.
        # Calaulate total cp value, weight and utility.
        if method_one_list[i][4] == 0:
            # Situation when the item is unread.
            # Calculate total cp value, weight and utility.
            total_cp_value_one += method_one_list[i][0]
            total_weight_one += int(method_one_list[i][1])
            total_utility_one += method_one_list[i][2]

            # Store index, cp value, weight and minimal number of items.
            index = method_one_list[i][3]
            max_cp_value = method_one_list_copy[index-1][0]
            min_weight = method_one_list_copy[index-1][1]
            min_number = method_one_list_copy[index-1][3]

            # Compare the choosen item and compare with other items.
            for j in range(len(method_one_list)):
                if max_cp_value == method_one_list[j][0]:
                    # Situation when two items with same cp value.
                    if min_weight == method_one_list[j][1]:
                        # Situation when two items with same weight.
                        if min_number > method_one_list[j][3]:
                            # Pick the item with smaller number.
                            min_number = method_one_list[j][3]
                            index = method_one_list[j][3]
                            # Mark the item as read.
                            method_one_list[j][4] = 1
                    elif min_weight > method_one_list[j][1]:
                        # Pick the item with smaller number.
                        min_weight = method_one_list[j][1]
                        index = method_one_list[j][3]
                        # Mark the item as read.
                        method_one_list[j][4] = 1
            # Store all indeces of chosen number.
            answer_list_one.append(index)
answer_list_one.sort()  # Sort answer_list_one.

# Situation when the list is empty.
if len(answer_list_one) == 0:
    answer_list_one.append(0)

# Method 2
method_two_list = []  # Create a list to store answer element.
for i in range(number_of_item):   # Check every item.
    # Create a list with (utility, weight, numebr(from 1 to n))
    lst = []
    lst.append(int(utility_list[i]))
    lst.append(int(weight_list[i]))
    lst.append(i+1)
    method_two_list.append(lst)  # Store lst in method_two_list.

# Sort and reverse method_two_list.
method_two_list.sort()
method_two_list.reverse()

total_weight_two = 0  # Space to store total weight.
total_utility_two = 0  # Space to store total utility.
answer_list_two = []  # Create a list to store answer element.

# Check every item and calculate total weight and utility.
for i in range(len(method_two_list)):
    if total_weight_two + int(method_two_list[i][1]) <= upper_limit:
        # Situation when total_weight is smaller than or equal to upper_limit.
        total_utility_two += int(method_two_list[i][0])
        total_weight_two += int(method_two_list[i][1])
        answer_list_two.append(method_two_list[i][2])
answer_list_two.sort()  # Sort answer_list_two.

if len(answer_list_two) == 0:  # Situation when the list is empty.
    answer_list_two.append(0)

# Compare total utilities of two methods.
if total_utility_one > total_utility_two:
    for i in range(len(answer_list_one)):
        # Choose method one.
        if i == len(answer_list_one)-1:
            print(answer_list_one[i], end="")
        else:
            print(answer_list_one[i], end="")
            print(",", end="")
elif total_utility_one < total_utility_two:
    for i in range(len(answer_list_two)):
        # Choose method two.
        if i == len(answer_list_two)-1:
            print(answer_list_two[i], end="")
        else:
            print(answer_list_two[i], end="")
            print(",", end="")
elif total_utility_one == total_utility_two:
    for i in range(len(answer_list_two)):
        # Choose method two.
        if i == len(answer_list_two)-1:
            print(answer_list_two[i], end="")
        else:
            print(answer_list_two[i], end="")
            print(",", end="s")
# Out:
# 5,9
# 2,3,4,3,8
# 2,4,5,3,10
# 1,2,3

# %%
# 10/25 12:00
# Store all inputs.
line_one = input()
line_two = input()
line_three = input()

# Split inputs and store in respective space.
line_one = line_one.split(",")
number_of_item = int(line_one[0])  # number_of_item is n.
upper_limit = int(line_one[1])  # upper_limit is B.
weight_list = line_two.split(",")  # List with numbers of weight.
utility_list = line_three.split(",")  # List with numbers of utility.

# Method 1
method_one_list = []
# Store sublists into another list. 
for i in range(number_of_item):
    # Create a list with (cp value, weight, utility, numebr(from 1 to n)).
    lst = []
    lst.append(int(utility_list[i])/int(weight_list[i]))
    lst.append(int(weight_list[i]))
    lst.append(int(utility_list[i]))
    lst.append(i+1)
    lst.append(0)
    # Store the lst into method_one_list.
    method_one_list.append(lst)

method_one_list_copy = []
for i in range(len(method_one_list)):
    method_one_list_copy.append(method_one_list[i])
# print("method_one_list_copy:",method_one_list_copy)
method_one_list.sort()
method_one_list.reverse()
# print("method_one_list:", method_one_list)

total_weight_one = 0
total_cp_value_one = 0
total_utility_one = 0
answer_list_one = []
answer_information_list = []
for i in range(number_of_item):
    # list with (cp value, weight, utility, numebr(from 1 to n))
    for j in range(number_of_item):
        method_one_list[j][4] = 0
    if total_weight_one + int(method_one_list[i][1]) <= upper_limit:
        if method_one_list[i][4] == 0:
            total_cp_value_one+=method_one_list[i][0]
            total_weight_one+=int(method_one_list[i][1])
            total_utility_one+=method_one_list[i][2]

            index = method_one_list[i][3]
            max_cp_value = method_one_list_copy[index-1][0]
            min_weight = method_one_list_copy[index-1][1]
            min_number = method_one_list_copy[index-1][3]
#             method_one_list[i][4] = 1
            for j in range(len(method_one_list)):
                if max_cp_value == method_one_list[j][0]:
                    if min_weight == method_one_list[j][1]:
                        if min_number > method_one_list[j][3]:
                            min_number = method_one_list[j][3]
                            index = method_one_list[j][3]
                            method_one_list[j][4] = 1
                    elif min_weight > method_one_list[j][1]:
                        min_weight = method_one_list[j][1]
                        index = method_one_list[j][3]
                        method_one_list[j][4] = 1
            answer_list_one.append(index)
            answer_information_list.append(method_one_list[i])
answer_list_one.sort()
# print("answer_list_one:",answer_list_one)

# print("nswer_information_list:",answer_information_list)

if len(answer_list_one) == 0:
    answer_list_one.append(0)

# Method 2
method_two_list = [] 
for i in range(number_of_item):
    # Create a list with (utility, weight, numebr(from 1 to n))
    lst = []
    lst.append(int(utility_list[i]))
    lst.append(int(weight_list[i]))
    lst.append(i+1)
    method_two_list.append(lst)
method_two_list.sort()
method_two_list.reverse()

total_weight_two = 0
total_utility_two = 0
answer_list_two = []
for i in range(len(method_two_list)):
    # list with (utility, weight, numebr(from 1 to n))
    if total_weight_two + int(method_two_list[i][1]) <= upper_limit:
        total_utility_two+=int(method_two_list[i][0])
        total_weight_two+=int(method_two_list[i][1])
        answer_list_two.append(method_two_list[i][2])
answer_list_two.sort()

if len(answer_list_two) == 0:
    answer_list_two.append(0)


if total_utility_one > total_utility_two:
    for i in range(len(answer_list_one)):
        if i == len(answer_list_one)-1:
            print(answer_list_one[i], end="")
        else:
            print(answer_list_one[i], end="")
            print(",", end="")
elif total_utility_one < total_utility_two:
    for i in range(len(answer_list_two)):
        if i == len(answer_list_two)-1:
            print(answer_list_two[i], end="")
        else:
            print(answer_list_two[i], end="")
            print(",", end="")
elif total_utility_one == total_utility_two:
    for i in range(len(answer_list_two)):
        if i == len(answer_list_two)-1:
            print(answer_list_two[i], end="")
        else:
            print(answer_list_two[i], end="")
            print(",", end="")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-656c51f7ea95> in <module>
#       1 # 10/25 12:00
#       2 # Store all inputs.
# ----> 3 line_one = input()
#       4 line_two = input()
#       5 line_three = input()
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
if len([]) == 0:
    print(0)

# %%
# 10/25 24:00
line_one = input()
line_two = input()
line_three = input()

line_one = line_one.split(",")
number_of_item = int(line_one[0])
upper_limit = int(line_one[1])
weight_list = line_two.split(",")
utility_list = line_three.split(",")

# method 1
method_one_list = []
for i in range(number_of_item):
    # Create a list with (cp value, weight, utility, numebr(from 1 to n))
    lst = []
    lst.append(int(utility_list[i])/int(weight_list[i]))
    lst.append(int(weight_list[i]))
    lst.append(int(utility_list[i]))
    lst.append(i+1)
    lst.append(0)
    method_one_list.append(lst)

method_one_list_copy = []
for i in range(len(method_one_list)):
    method_one_list_copy.append(method_one_list[i])
# print("method_one_list_copy:",method_one_list_copy)
method_one_list.sort()
method_one_list.reverse()
# print("method_one_list:", method_one_list)

total_weight_one = 0
total_cp_value_one = 0
total_utility_one = 0
answer_list_one = []
answer_information_list = []
for i in range(number_of_item):
    # list with (cp value, weight, utility, numebr(from 1 to n))
    if total_weight_one + int(method_one_list[i][1]) <= upper_limit:
        total_cp_value_one+=method_one_list[i][0]
        total_weight_one+=int(method_one_list[i][1])
        total_utility_one+=method_one_list[i][2]
        answer_list_one.append(method_one_list[i][3])
        answer_information_list.append(method_one_list[i])
answer_list_one.sort()
# print("answer_list_one",answer_list_one)

answer_list_one_new = []
# print("answer_information_list:", answer_information_list)
for i in range(len(answer_list_one)):
    index = answer_information_list[i][3]
    max_cp_value = method_one_list_copy[index-1][0]
    min_weight = method_one_list_copy[index-1][1]
    min_number = method_one_list_copy[index-1][3]
    method_one_list[i][4] = 1
    for j in range(len(method_one_list)):
        if max_cp_value == method_one_list[j][0]:
            if min_weight == method_one_list[j][1]:
                if min_number > method_one_list[j][1]:
                    index = method_one_list[j][3]
                    method_one_list[j][4] = 1
            elif min_weight > method_one_list[j][1]:
                index = method_one_list[j][3]
                method_one_list[j][4] = 1
    answer_list_one_new.append(index)
# print("answer_list_one_new:", answer_list_one_new)
answer_list_one_new.sort()
answer_list_one = answer_list_one_new



### method 2
method_two_list = [] 
for i in range(number_of_item):
    # Create a list with (utility, weight, numebr(from 1 to n))
    lst = []
    lst.append(int(utility_list[i]))
    lst.append(int(weight_list[i]))
    lst.append(i+1)
    method_two_list.append(lst)
method_two_list.sort()
method_two_list.reverse()

total_weight_two = 0
total_utility_two = 0
answer_list_two = []
for i in range(len(method_two_list)):
    # list with (utility, weight, numebr(from 1 to n))
    if total_weight_two + int(method_two_list[i][1]) <= upper_limit:
        total_utility_two+=int(method_two_list[i][0])
        total_weight_two+=int(method_two_list[i][1])
        answer_list_two.append(method_two_list[i][2])
answer_list_two.sort()

if total_utility_one > total_utility_two:
    for i in range(len(answer_list_one)):
        if i == len(answer_list_one)-1:
            print(answer_list_one[i], end="")
        else:
            print(answer_list_one[i], end="")
            print(",", end="")
elif total_utility_one < total_utility_two:
    for i in range(len(answer_list_two)):
        if i == len(answer_list_two)-1:
            print(answer_list_two[i], end="")
        else:
            print(answer_list_two[i], end="")
            print(",", end="")
elif total_utility_one == total_utility_two:
    for i in range(len(answer_list_two)):
        if i == len(answer_list_two)-1:
            print(answer_list_two[i], end="")
        else:
            print(answer_list_two[i], end="")
            print(",", end="")

# %%
# 10/24 13:00
line_one = input()
line_two = input()
line_three = input()

line_one = line_one.split(",")
number_of_item = int(line_one[0])
upper_limit = int(line_one[1])
weight_list = line_two.split(",")
utility_list = line_three.split(",")

# method 1
method_one_list = []
for i in range(number_of_item):
    # Create a list with (cp value, weight, utility, numebr(from 1 to n))
    lst = []
    lst.append(int(utility_list[i])/int(weight_list[i]))
    lst.append(int(weight_list[i]))
    lst.append(int(utility_list[i]))
    lst.append(i+1)
    method_one_list.append(lst)
method_one_list.sort()
method_one_list.reverse()

total_weight_one = 0
total_cp_value_one = 0
total_utility_one = 0
answer_list_one = []
answer_information_list = []



# ################
# weight_list = []
# utility_list = []
# index_list = []
# # 當同值數量大於1時，選後面的
# #################

for i in range(number_of_item):
    # list with (cp value, weight, utility, numebr(from 1 to n))
    if total_weight_one + int(method_one_list[i][1]) <= upper_limit:
        total_cp_value_one+=method_one_list[i][0]
        total_weight_one+=int(method_one_list[i][1])
        total_utility_one+=method_one_list[i][2]
        answer_list_one.append(method_one_list[i][3])
        answer_information_list.append(method_one_list[i])
answer_list_one.sort()


"""
answer_list_one_new = []
for i in range(len(answer_information_list)):
    same_cp_value_weight_list = []
    same_cp_value_list = []
    cp_value = answer_information_list[i][0]
    weight = int(answer_information_list[i][1])
    utility = answer_information_list[i][2]
    number = answer_information_list[i][3]
    same_cp_value_weight_list.append(answer_information_list[i])
    same_cp_value_list.append(answer_information_list[i])

    for j in range(len(method_one_list)):
        if number != method_one_list[j][3]:
            if cp_value == method_one_list[j][0] and weight == method_one_list[j][1]:
                same_cp_value_weight_list.append(method_one_list[j])
            elif cp_value == method_one_list[j][0]:
                same_cp_value_list.append(method_one_list[j])
    
    if len(same_cp_value_list) > 1:
        original_index = same_cp_value_list[0][3]
        answer_list_one.remove(original_index)
        for k in range(len(same_cp_value_list)):
            same_cp_value_list[k].insert(0,same_cp_value_list[k][1])
        same_cp_value_list.sort()
        answer_list_one_new.append(same_cp_value_list[0][4])
        answer_list_one.append(same_cp_value_list[0][4])

    if len(same_cp_value_weight_list) > 1:
        original_index = same_cp_value_list[0][3]
        answer_list_one.remove(original_index)
        for k in range(len(same_cp_value_weight_list)):
            same_cp_value_weight_list[k].insert(0,same_cp_value_weight_list[k][3])
        same_cp_value_weight_list.sort()
        answer_list_one_new.append(same_cp_value_weight_list[0][4])
        answer_list_one.append(same_cp_value_weight_list[0][4])
answer_list_one.sort()
"""


### method 2
method_two_list = [] 
for i in range(number_of_item):
    # Create a list with (utility, weight, numebr(from 1 to n))
    lst = []
    lst.append(int(utility_list[i]))
    lst.append(int(weight_list[i]))
    lst.append(i+1)
    method_two_list.append(lst)
method_two_list.sort()
method_two_list.reverse()

total_weight_two = 0
total_utility_two = 0
answer_list_two = []

for i in range(len(method_two_list)):
    # list with (utility, weight, numebr(from 1 to n))
    if total_weight_two + int(method_two_list[i][1]) <= upper_limit:
        total_utility_two+=int(method_two_list[i][0])
        total_weight_two+=int(method_two_list[i][1])
        answer_list_two.append(method_two_list[i][2])
answer_list_two.sort()

if total_utility_one > total_utility_two:
    for i in range(len(answer_list_one)):
        if i == len(answer_list_one)-1:
            print(answer_list_one[i], end="")
        else:
            print(answer_list_one[i], end=""),
            print(",", end="")
elif total_utility_one < total_utility_two:
    for i in range(len(answer_list_two)):
        if i == len(answer_list_two)-1:
            print(answer_list_two[i], end="")
        else:
            print(answer_list_two[i], end="")
            print(",", end="")
elif total_utility_one == total_utility_two:
    for i in range(len(answer_list_two)):
        if i == len(answer_list_two)-1:
            print(answer_list_two[i], end="")
        else:
            print(answer_list_two[i], end="")
            print(",", end="")

# %%
# 10/24 12:00
line_one = input()
line_two = input()
line_three = input()

line_one = line_one.split(",")
number_of_item = int(line_one[0])
upper_limit = int(line_one[1])
weight_list = line_two.split(",")
utility_list = line_three.split(",")

# method 1
method_one_list = []
for i in range(number_of_item):
    # Create a list with (cp value, weight, utility, numebr(from 1 to n))
    lst = []
    lst.append(int(utility_list[i])/int(weight_list[i]))
    lst.append(int(weight_list[i]))
    lst.append(int(utility_list[i]))
    lst.append(i+1)
    method_one_list.append(lst)
method_one_list.sort()
method_one_list.reverse()
# print("method_one_list")
# print(method_one_list)

# copy_cp_value_list = []
# for i in range(len(method_two_list)):
#     copy_cp_value_list.append(method_two_list[i])
# print(copy_cp_value_list)
# reverse_cp_value_list = sorted(copy_cp_value_list)
# print(reverse_cp_value_list)
# reverse_cp_value_list.reverse()
# print(reverse_cp_value_list)

total_weight_one = 0
total_cp_value_one = 0
total_utility_one = 0
answer_list_one = []
answer_information_list = []
for i in range(number_of_item):
    # list with (cp value, weight, utility, numebr(from 1 to n))
    if total_weight_one + int(method_one_list[i][1]) <= upper_limit:
        total_cp_value_one+=method_one_list[i][0]
        total_weight_one+=int(method_one_list[i][1])
        total_utility_one+=method_one_list[i][2]
        answer_list_one.append(method_one_list[i][3])
        answer_information_list.append(method_one_list[i])
# print("total_cp_value_one")
# print(total_cp_value_one)
# print("total_weight_one")
# print(total_weight_one)
# print("total_utility_one")
# print(total_utility_one)
# print("answer_list_one")
answer_list_one.sort()
# print(answer_list_one)
# print("answer_information_list")
# print(answer_information_list)


answer_list_one_new = []
# same_cp_value_list = []
# same_cp_value_weight_list = []
for i in range(len(answer_information_list)):
#     print(i)
#     print("answer_information_list")
#     print(answer_information_list)
#     print("method_one_list")
#     print(method_one_list)
#     print("method_one_list[i]")
#     print(method_one_list[i])
    same_cp_value_weight_list = []
    same_cp_value_list = []
    cp_value = answer_information_list[i][0]
    weight = int(answer_information_list[i][1])
    utility = answer_information_list[i][2]
    number = answer_information_list[i][3]
#     print("number")
#     print(number)
#     answer_list_one.remove(number)
    same_cp_value_weight_list.append(answer_information_list[i])
    same_cp_value_list.append(answer_information_list[i])

    for j in range(len(method_one_list)):
#         print("Compare cp_value and weight")
#         print(cp_value)
#         print(method_one_list[j][0])
#         print(weight)
#         print(method_one_list[j][1])
        if number != method_one_list[j][3]:
            if cp_value == method_one_list[j][0] and weight == method_one_list[j][1]:
                same_cp_value_weight_list.append(method_one_list[j])
            elif cp_value == method_one_list[j][0]:
                same_cp_value_list.append(method_one_list[j])
#     print("same_cp_value_list")
#     print(same_cp_value_list)
#     print("same_cp_value_weight_list")
#     print(same_cp_value_weight_list)
    
    if len(same_cp_value_list) > 1:
#         print("111")
        original_index = same_cp_value_list[0][3]
        answer_list_one.remove(original_index)
        for k in range(len(same_cp_value_list)):
#                 print("same_cp_value_list[k][1]")
#                 print(same_cp_value_list[k][1])
            same_cp_value_list[k].insert(0,same_cp_value_list[k][1])
#         print("same_cp_value_list")
#         print(same_cp_value_list)

        same_cp_value_list.sort()
#         print("same_cp_value_list(sorted)")
#         print(same_cp_value_list)
        answer_list_one_new.append(same_cp_value_list[0][4])
        
        answer_list_one.append(same_cp_value_list[0][4])
#           answer_list_one.remove(number)
#             answer_list_one.append(same_cp_value_list[0][0])

    if len(same_cp_value_weight_list) > 1:
#         print("222")
        original_index = same_cp_value_list[0][3]
        answer_list_one.remove(original_index)
        for k in range(len(same_cp_value_weight_list)):
#                 print("same_cp_value_weight_list[k][3]")
#                 print(same_cp_value_weight_list[k][3])
            same_cp_value_weight_list[k].insert(0,same_cp_value_weight_list[k][3])
#         print("same_cp_value_weight_list")
#         print(same_cp_value_weight_list)
        same_cp_value_weight_list.sort()
#         print("same_cp_value_weight_list(sorted)")
#         print(same_cp_value_weight_list)
#           answer_list_one.remove(number)
        answer_list_one_new.append(same_cp_value_weight_list[0][0])
        answer_list_one.append(same_cp_value_list[0][4])
#         print("answer_list_one_new")
#         print(answer_list_one_new)
# print("answer_list_one_new")
# print(answer_list_one_new)


answer_list_one.sort()
# print("answer_list_one")
# print(answer_list_one)


### method 2
method_two_list = [] 
for i in range(number_of_item):
    # Create a list with (utility, weight, numebr(from 1 to n))
    lst = []
    lst.append(int(utility_list[i]))
    lst.append(int(weight_list[i]))
    lst.append(i+1)
#     print(lst)
    method_two_list.append(lst)
# print("method_two_list")
# print(method_two_list)
method_two_list.sort()
method_two_list.reverse()
# print("method_two_list(sorted)")
# print(method_two_list)
# print("len(method_two_list)")
# print(len(method_two_list))

total_weight_two = 0
total_utility_two = 0
answer_list_two = []
for i in range(len(method_two_list)):
    # list with (utility, weight, numebr(from 1 to n))
    if total_weight_two + int(method_two_list[i][1]) <= upper_limit:
        total_utility_two+=int(method_two_list[i][0])
        total_weight_two+=int(method_two_list[i][1])
        answer_list_two.append(method_two_list[i][2])
# print("total_utility_two")
# print(total_utility_two)
# print("total_weight_two")
# print(total_weight_two)
# print("answer_list_two")
answer_list_two.sort()
# print(answer_list_two)

# print("answer_list_one")
# print(answer_list_one)
if total_utility_one > total_utility_two:
    for i in range(len(answer_list_one)):
        if i == len(answer_list_one)-1:
            print(answer_list_one[i], end="")
        else:
            print(answer_list_one[i], end=""),
            print(",", end="")
elif total_utility_one < total_utility_two:
    for i in range(len(answer_list_two)):
        if i == len(answer_list_two)-1:
            print(answer_list_two[i], end="")
        else:
            print(answer_list_two[i], end="")
            print(",", end="")
elif total_utility_one == total_utility_two:
    for i in range(len(answer_list_two)):
        if i == len(answer_list_two)-1:
            print(answer_list_two[i], end="")
        else:
            print(answer_list_two[i], end="")
            print(",", end="")

# %%
line_one = input()
line_two = input()
line_three = input()

line_one = line_one.split(",")
number_of_item = int(line_one[0])
upper_limit = int(line_one[1])
weight_list = line_two.split(",")
utility_list = line_three.split(",")

# method 1
method_one_list = []
for i in range(number_of_item):
    # Create a list with (cp value, weight, utility, numebr(from 1 to n))
    lst = []
    lst.append(int(utility_list[i])/int(weight_list[i]))
    lst.append(int(weight_list[i]))
    lst.append(int(utility_list[i]))
    lst.append(i+1)
    method_one_list.append(lst)
method_one_list.sort()
method_one_list.reverse()
print("method_one_list")
print(method_one_list)

total_weight_one = 0
total_cp_value_one = 0
total_utility_one = 0
answer_list_one = []
answer_number_list = []
copy_method_one_list_reverse = []
for i in range(len(method_one_list)):
    copy_method_one_list_reverse.append(method_one_list)
copy_method_one_list_reverse.sort()
copy_method_one_list_reverse.reverse()
print("copy_method_one_list_reverse")
print(copy_method_one_list_reverse)

for i in range(number_of_item):
    # list with (cp value, weight, utility, numebr(from 1 to n))
    cp_value = method_one_list[i][0]
    weight = int(method_one_list[i][1])
    utility = method_one_list[i][2]
    number = method_one_list[i][3]
    if total_weight_one + weight <= upper_limit:
        for j in range(number_of_item):
            if number != method_one_list[j][3]:
                if cp_value == method_one_list[j][0]:
                    if weight == method_one_list[j][1]:
                        if number > method_one_list[j][3]:
                            total_cp_value_one+=method_one_list[j][0]
                            total_weight_one+=int(method_one_list[j][1])
                            total_utility_one+=method_one_list[j][2]
                            answer_list_one.append(method_one_list[j][3])
                            answer_number_list.append(method_one_list[j][3])
                            break
                        else:
                            total_cp_value_one+=method_one_list[i][0]
                            total_weight_one+=int(method_one_list[i][1])
                            total_utility_one+=method_one_list[i][2]
                            answer_list_one.append(method_one_list[i][3])
                            answer_number_list.append(method_one_list[i][3])
                            break
                    elif weight < method_one_list[j][1]:
                        total_cp_value_one+=method_one_list[i][0]
                        total_weight_one+=int(method_one_list[i][1])
                        total_utility_one+=method_one_list[i][2]
                        answer_list_one.append(method_one_list[i][3])
                        answer_number_list.append(method_one_list[i][3])
                        break
                    elif weight > method_one_list[j][1]:
                            total_cp_value_one+=method_one_list[j][0]
                            total_weight_one+=int(method_one_list[j][1])
                            total_utility_one+=method_one_list[j][2]
                            answer_list_one.append(method_one_list[j][3])
                            answer_number_list.append(method_one_list[j][3])
                            break
                elif cp_value > method_one_list[j][0]:
                    total_cp_value_one+=method_one_list[i][0]
                    total_weight_one+=int(method_one_list[i][1])
                    total_utility_one+=method_one_list[i][2]
                    answer_list_one.append(method_one_list[i][3])
                    answer_number_list.append(method_one_list[i][3])
                    break 
            
# print("total_weight_one")
# print(total_weight_one)
# print("total_utility_one")
# print(total_utility_one)
# print("answer_list_one")
answer_list_one.sort()
# print(answer_list_one)



### method 2
method_two_list = [] 
for i in range(number_of_item):
    # Create a list with (utility, weight, numebr(from 1 to n))
    lst = []
    lst.append(int(utility_list[i]))
    lst.append(int(weight_list[i]))
    lst.append(i+1)
#     print(lst)
    method_two_list.append(lst)
# print("method_two_list")
# print(method_two_list)
method_two_list.sort()
method_two_list.reverse()
# print("method_two_list(sorted)")
# print(method_two_list)
# print("len(method_two_list)")
# print(len(method_two_list))

total_weight_two = 0
total_utility_two = 0
answer_list_two = []
for i in range(len(method_two_list)):
    # list with (utility, weight, numebr(from 1 to n))
    if total_weight_two + int(method_two_list[i][1]) <= upper_limit:
        total_utility_two+=int(method_two_list[i][0])
        total_weight_two+=int(method_two_list[i][1])
        answer_list_two.append(method_two_list[i][2])
# print("total_utility_two")
# print(total_utility_two)
# print("total_weight_two")
# print(total_weight_two)
# print("answer_list_two")
answer_list_two.sort()
# print(answer_list_two)

# print("answer_list_one")
# print(answer_list_one)
if total_utility_one > total_utility_two:
    for i in range(len(answer_list_one)):
        if i == len(answer_list_one)-1:
            print(answer_list_one[i], end="")
        else:
            print(answer_list_one[i], end="")
            print(",", end="")
elif total_utility_one < total_utility_two:
    for i in range(len(answer_list_two)):
        if i == len(answer_list_two)-1:
            print(answer_list_two[i], end="")
        else:
            print(answer_list_two[i], end="")
            print(",", end="")
elif total_utility_one == total_utility_two:
    for i in range(len(answer_list_two)):
        if i == len(answer_list_two)-1:
            print(answer_list_two[i], end="")
        else:
            print(answer_list_two[i], end="")
            print(",", end="")

# %%
line_one = input()
line_two = input()
line_three = input()

line_one = line_one.split(",")
number_of_item = int(line_one[0])
upper_limit = int(line_one[1])
weight_list = line_two.split(",")
utility_list = line_three.split(",")

# method 1
method_one_list = []
for i in range(number_of_item):
    # Create a list with (cp value, weight, utility, numebr(from 1 to n))
    lst = []
    lst.append(int(utility_list[i])/int(weight_list[i]))
    lst.append(int(weight_list[i]))
    lst.append(int(utility_list[i]))
    lst.append(i+1)
    method_one_list.append(lst)
method_one_list.sort()
method_one_list.reverse()
print("method_one_list")
print(method_one_list)

total_weight_one = 0
total_cp_value_one = 0
total_utility_one = 0
answer_list_one = []
answer_information_list = []
for i in range(number_of_item):
    # list with (cp value, weight, utility, numebr(from 1 to n))
    if total_weight_one + int(method_one_list[i][1]) <= upper_limit:
        total_cp_value_one+=method_one_list[i][0]
        total_weight_one+=int(method_one_list[i][1])
        total_utility_one+=method_one_list[i][2]
#         answer_list_one.append(method_one_list[i][3])
        answer_information_list.append(method_one_list[i])

print("answer_information_list")
print(answer_information_list)

for i in range(len(answer_information_list)):
    for j in range(len(method_one_list)):
        if answer_information_list[i][0] == method_one_list[j][0]:
            if answer_information_list[i][1] > method_one_list[j][1]:
                answer_information_list.pop(i)
                answer_list_one.append(method_one_list[j])
            elif answer_information_list[i][1] == method_one_list[j][1]:
                if answer_information_list[i][2] > method_one_list[j][2]:
                    answer_information_list.pop(i)
                    answer_list_one.append(method_one_list[j])
print("answer_information_list(changed)")
print(answer_information_list)

for i in range(len(answer_information_list)):
    answer_list_one.append(answer_information_list[i][3])
# print("answer_list_one")
answer_list_one.sort()
# print(answer_list_one)



### method 2
method_two_list = [] 
for i in range(number_of_item):
    # Create a list with (utility, weight, numebr(from 1 to n))
    lst = []
    lst.append(int(utility_list[i]))
    lst.append(int(weight_list[i]))
    lst.append(i+1)
#     print(lst)
    method_two_list.append(lst)
# print("method_two_list")
# print(method_two_list)
method_two_list.sort()
method_two_list.reverse()
# print("method_two_list(sorted)")
# print(method_two_list)
# print("len(method_two_list)")
# print(len(method_two_list))

total_weight_two = 0
total_utility_two = 0
answer_list_two = []
for i in range(len(method_two_list)):
    # list with (utility, weight, numebr(from 1 to n))
    if total_weight_two + int(method_two_list[i][1]) <= upper_limit:
        total_utility_two+=int(method_two_list[i][0])
        total_weight_two+=int(method_two_list[i][1])
        answer_list_two.append(method_two_list[i][2])
# print("total_utility_two")
# print(total_utility_two)
# print("total_weight_two")
# print(total_weight_two)
# print("answer_list_two")
answer_list_two.sort()
# print(answer_list_two)

# print("answer_list_one")
# print(answer_list_one)
if total_utility_one > total_utility_two:
    for i in range(len(answer_list_one)):
        if i == len(answer_list_one)-1:
            print(answer_list_one[i], end="")
        else:
            print(answer_list_one[i], end="")
            print(",", end="")
elif total_utility_one < total_utility_two:
    for i in range(len(answer_list_two)):
        if i == len(answer_list_two)-1:
            print(answer_list_two[i], end="")
        else:
            print(answer_list_two[i], end="")
            print(",", end="")
elif total_utility_one == total_utility_two:
    for i in range(len(answer_list_two)):
        if i == len(answer_list_two)-1:
            print(answer_list_two[i], end="")
        else:
            print(answer_list_two[i], end="")
            print(",", end="")

# %%
lst = list()
lst.append([1,3])
lst.append([2,5])
lst.append([3,1])
print(lst)

# %%
lst.sort()
print(lst)

# %%
lst = list()
lst.append([3,1])
lst.append([5,2])
lst.append([1,3])
lst.append([4,4])
print(lst)

# %%
lst.sort()
print(lst)

# %%
lst = list()
lst.append([4,2,1])
lst.append([4,1,2])
lst.append([3,2,3])
lst.append([3,1,4])
lst.append([3,1,2])
lst.append([4,1,4])
print(lst)

# %%
lst.sort()
print(lst)

# %%
lst.reverse()
print(lst)
