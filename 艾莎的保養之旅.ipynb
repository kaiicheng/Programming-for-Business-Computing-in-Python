# %%
day = int(input())
total_sleep_time = 0
day_over_seven_hour = 0
day_not_over_seven_hour = 0
total_sleep_time = 0
lemon_mask = 0
syrup_mask = 0
protein_mask = 0

for i in range(day):
    day_sleep_hour = float(input())
    total_sleep_time += day_sleep_hour
    if day_sleep_hour > 7:
        day_over_seven_hour += 1
    else:
        day_not_over_seven_hour += 1

average_sleep_hour = total_sleep_time/day
n_minus_m = day - day_over_seven_hour
# Number of lemon mask.
lemon_mask = day_over_seven_hour
if average_sleep_hour <= 6:
    # Number of syrup mask.
    syrup_mask = n_minus_m
else:
    # Number of protein mask.
    protein_mask = n_minus_m

# Calculate units of materials.
lemon = lemon_mask*1.5
almond = lemon_mask*4 + syrup_mask*9
honey = syrup_mask*18 + protein_mask*6
egg = protein_mask*2

# Calculate price of lemon.
if lemon - int(lemon) > 0:
    lemon = int(lemon)+1
if lemon >= 5:
    lemon_price = lemon*7*0.9
else:
    lemon_price = lemon*7

# Calculate price of almond.
almond_price = almond*0.6

# Calculate price of honey.
honey_price = honey*1.2

# Calcutae price of egg.
if egg/3-int(int(egg/3)):
    egg_price = (int(egg/3)+1)*25
else:
    egg_price = (int(egg/3))*25

# Sum up total price.
price = almond_price + honey_price + lemon_price + egg_price
price = int(price)
print(price)

# %%
day = int(input())

total_sleep_time = 0
# day_sleep_over_seven_hour = 0
# day_sleep_not_over_seven_hour = 0
day_over_seven_hour = 0
day_not_over_seven_hour = 0
total_sleep_time = 0
lemon_mask = 0
syrup_mask = 0
protein_mask = 0

for i in range(day):
    day_sleep_hour = float(input())
    total_sleep_time += day_sleep_hour
    if day_sleep_hour > 7:
        # 檸檬美白面膜
        day_over_seven_hour += 1
    else:
        day_not_over_seven_hour += 1
# print("day_over_seven_hour:")
# print(day_over_seven_hour)

# print("day_not_over_seven_hour:")
# print(day_not_over_seven_hour)

average_sleep_hour = total_sleep_time/day
# print("average_sleep_hour:")
# print(average_sleep_hour)

n_minus_m = day - day_over_seven_hour
# print("n_minus_m:")
# print(n_minus_m)

# 檸檬美白面膜
lemon_mask = day_over_seven_hour

if average_sleep_hour <= 6:
    # 蜜糖修復面膜
    syrup_mask = n_minus_m
else:
    protein_mask = n_minus_m
    
# print("lemon_mask:")
# print(lemon_mask)
# print("syrup_mask:")
# print(syrup_mask)
# print("protein_mask:")
# print(protein_mask)

"""
# 檸檬美白面膜需要 1.5 顆檸檬、4 單位的杏仁油
# 檸檬一顆售價 7 元，只能買整數顆檸檬，買五顆以上（包含）每顆檸檬打 9 折
# 杏仁油每單位 0.6 元

lemon = lemon_mask*1.5
almond = lemon_mask*4

# 一張蜜糖修復面膜需要 18 單位的蜂蜜、9 單位的杏仁油
# 杏仁油每單位 0.6 元
# 蜂蜜每單位 1.2 元
honey = syrup_mask*18
almond = syrup_mask*9

# 一張蛋白彈潤面膜需要 2 顆雞蛋、6 單位蜂蜜
# 雞蛋每盒三顆，每盒 25 元
# 蜂蜜每單位 1.2 元
egg = protein_mask*2
honey = protein_mask*6

# Total
lemon = lemon_mask*1.5
almond = lemon_mask*4 + syrup_mask*9
honey = syrup_mask*18 + protein_mask*6
egg = protein_mask*2
    
# ，總金額會進行無條件捨去以整數計算。
"""
lemon = lemon_mask*1.5
almond = lemon_mask*4 + syrup_mask*9
honey = syrup_mask*18 + protein_mask*6
egg = protein_mask*2

# print("lemon:")
# print(lemon)
# print("almond:")
# print(almond)
# print("honey:")
# print(honey)
# print("egg:")
# print(egg)


# print("int(lemon):")
# print(int(lemon))
if lemon - int(lemon) > 0:
    lemon = int(lemon)+1

if lemon >= 5:
    lemon_price = lemon*7*0.9
else:
    lemon_price = lemon*7

# print("almond:")
# print(almond)
almond_price = almond*0.6

honey_price = honey*1.2


# print("egg:")
# print(egg)
# print(int(egg))
# print(egg/3)
# print(int(egg/3))
# print(int(egg/3)+1)

if egg/3-int(int(egg/3)):
    egg_price = (int(egg/3)+1)*25
else:
    egg_price = (int(egg/3))*25

# print("lemon_price:")
# print(lemon_price)
# print("almond_price:")
# print(almond_price)
# print("honey_price:")
# print(honey_price)
# print("egg_price:")
# print(egg_price)


price = almond_price + honey_price + lemon_price + egg_price

price = int(price)
print(price)
# Out:
# 8
# 6.5
# 4.8
# 7.0
# 6.5
# 8.0
# 6.5
# 6.0
# 6.5
# 191
