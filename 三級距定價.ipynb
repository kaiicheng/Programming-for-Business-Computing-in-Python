# %%
kg_at_least = int(input())
kg_t1 = int(input())
price_r1 = int(input())
kg_t2 = int(input())
price_r2 = int(input())
kg_t3 = int(input())
price_r3 = int(input())
if kg_at_least >= kg_t3:
    total = (price_r1*kg_t1 +
             price_r2*(kg_t2-kg_t1) +
             price_r3*(kg_t3-kg_t2) +
             0*(kg_at_least-kg_t3))
elif kg_at_least >= kg_t2:
    total = (price_r1*kg_t1 +
             price_r2*(kg_t2-kg_t1) +
             price_r3*(kg_at_least-kg_t2))
elif kg_at_least >= kg_t1:
    total = price_r1*kg_t1 + price_r2*(kg_at_least-kg_t1)
elif kg_at_least <= kg_t1:
    total = price_r1*kg_at_least
print(total)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-fe97760bda2c> in <module>
# ----> 1 kg_at_least = int(input())
#       2 kg_t1 = int(input())
#       3 price_r1 = int(input())
#       4 kg_t2 = int(input())
#       5 price_r2 = int(input())
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# ...
